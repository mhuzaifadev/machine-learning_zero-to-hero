# %% [markdown]
# # **Tree Based Regression in ML**
#
# For detailed presentation [visit here](https://github.com/mhuzaifadev/ml_zero_to_hero/raw/master/Tree%20based%20Regression.pdf)

# %% [markdown]
# ## **Decision Trees**
#
# <img src="https://miro.medium.com/max/1630/1*XZ220vTa7rN8ccJZZNe09w.png">

# %% [markdown]
# ## **Get Started with Decision Tree**

# %%
#Importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## **Importing the Dataset**
#
# Reading ().csv file

# %%
dataset = pd.read_csv("/content/drive/My Drive/Datasets/Position_Salaries.csv")
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

X= np.array(X).reshape(-1,1)
y= np.array(y).reshape(-1,1)

# %% [markdown]
# ## **Splitting the Dataset into the Training Set and Test Set**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)

# %% [markdown]
# ## **Training the Model**

# %%
modelDT = DecisionTreeRegressor(random_state = 0)
modelDT.fit(X,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %% [markdown]
# ## **Tree Visualization**

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(modelDT,filled=True)
# Out:
# [Text(588.515625, 504.7714285714286, 'X[0] <= 8.5\nmse = 80662250000.0\nsamples = 10\nvalue = 249500.0'),
#  Text(444.65625, 427.11428571428576, 'X[0] <= 6.5\nmse = 6921484375.0\nsamples = 8\nvalue = 124375.0'),
#  Text(313.875, 349.4571428571429, 'X[0] <= 4.5\nmse = 1381250000.0\nsamples = 6\nvalue = 82500.0'),
#  Text(209.25, 271.8, 'X[0] <= 3.5\nmse = 179687500.0\nsamples = 4\nvalue = 58750.0'),
#  Text(156.9375, 194.14285714285717, 'X[0] <= 2.5\nmse = 38888888.889\nsamples = 3\nvalue = 51666.667'),
#  Text(104.625, 116.48571428571432, 'X[0] <= 1.5\nmse = 6250000.0\nsamples = 2\nvalue = 47500.0'),
#  Text(52.3125, 38.82857142857142, 'mse = 0.0\nsamples = 1\nvalue = 45000.0'),
#  Text(156.9375, 38.82857142857142, 'mse = 0.0\nsamples = 1\nvalue = 50000.0'),
#  Text(209.25, 116.48571428571432, 'mse = 0.0\nsamples = 1\nvalue = 60000.0'),
#  Text(261.5625, 194.14285714285717, 'mse = 0.0\nsamples = 1\nvalue = 80000.0'),
#  Text(418.5, 271.8, 'X[0] <= 5.5\nmse = 400000000.0\nsamples = 2\nvalue = 130000.0'),
#  Text(366.1875, 194.14285714285717, 'mse = 0.0\nsamples = 1\nvalue = 110000.0'),
#  Text(470.8125, 194.14285714285717, 'mse = 0.0\nsamples = 1\nvalue = 150000.0'),
#  Text(575.4375, 349.4571428571429, 'X[0] <= 7.5\nmse = 2500000000.0\nsamples = 2\nvalue = 250000.0'),
#  Text(523.125, 271.8, 'mse = 0.0\nsamples = 1\nvalue = 200000.0'),
#  Text(627.75, 271.8, 'mse = 0.0\nsamples = 1\nvalue = 300000.0'),
#  Text(732.375, 427.11428571428576, 'X[0] <= 9.5\nmse = 62500000000.0\nsamples = 2\nvalue = 750000.0'),
#  Text(680.0625, 349.4571428571429, 'mse = 0.0\nsamples = 1\nvalue = 500000.0'),
#  Text(784.6875, 349.4571428571429, 'mse = 0.0\nsamples = 1\nvalue = 1000000.0')]

# %% [markdown]
# ## **Prediction**

# %%
y_pred = modelDT.predict([[6.5]])
y_pred
# Out:
# array([150000.])

# %% [markdown]
# ## **Mean Squared Error**

# %%
regression_model_mse = mean_squared_error(y_test,modelDT.predict(X_test))
print('Mean Squared Error:\t',math.sqrt(regression_model_mse))
print("R squared value\t\t",modelDT.score(X,y))
# Out:
# Mean Squared Error:	 321908.37205639743
# R squared value		 1.0

# %% [markdown]
# ## **Visualization**

# %%
plt.scatter(X,y, color = 'red')
plt.plot(X, modelDT.predict(X), color = 'blue')
plt.title('Truth or Bluff (Decision tree Regression')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
